# %%
import pandas as pd
import numpy as np

# %%
col_names = ['command', 'label']
df = pd.read_csv('./Utilities/Datasets/Preprocessed/home_appliance.csv')

# %%
df.sample(frac=1).reset_index(drop=True)
# Out:
#                         command                label
# 0                  batti bujhaw   __label__light_off
# 1                      light on    __label__light_on
# 2                    off geyser  __label__geyser_off
# 3                    off geyser  __label__geyser_off
# 4                     off light   __label__light_off
# 5                  bulb jalaiye    __label__light_on
# 6                      light on    __label__light_on
# 7                    geyser off  __label__geyser_off
# 8                 bulb bujhaiye   __label__light_off
# 9     paani garam machine start   __label__geyser_on
# 10                  light bujha   __label__light_off
# 11                         dark   __label__light_off
# 12                    off light   __label__light_off
# 13  paani garam machiniya start   __label__geyser_on
# 14                  batti jalaw    __label__light_on
# 15     paani garam machine band  __label__geyser_off
# 16                  light chalu    __label__light_on
# 17                   balab band   __label__light_off
# 18                    light off   __label__light_off
# 19                   balab jala    __label__light_on
# 20                   batti jala    __label__light_on
# 21                    on geyser   __label__geyser_on
# 22                    on geyser   __label__geyser_on
# 23                  batti bujha   __label__light_off
# 24    paani garam machiniya off  __label__geyser_off
# 25                    geyser on   __label__geyser_on
# 26                  balab bujha   __label__light_off
# 27  paani garam machiniya chalu   __label__geyser_on
# 28                  balab chalu    __label__light_on
# 29                    bulb jala    __label__light_on
# 30                batti jalaiye    __label__light_on
# 31     machine band paani garam  __label__geyser_off
# 32                   off geyser  __label__geyser_off
# 33    machine chalu paani garam   __label__geyser_on
# 34       paani garam machine on   __label__geyser_on
# 35                   light band   __label__light_off
# 36    paani garam machine shuru   __label__geyser_on
# 37    paani garam machine chala   __label__geyser_on
# 38                   light jala    __label__light_on
# 39   paani garam machiniya band  __label__geyser_off
# 40      paani garam machine off  __label__geyser_off
# 41                    on geyser   __label__geyser_on
